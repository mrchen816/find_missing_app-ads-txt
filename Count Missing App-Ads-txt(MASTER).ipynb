# %% [markdown]
# ## Library Imports

# %%
import requests
import json
import pandas as pd
from requests.exceptions import HTTPError

# %% [markdown]
# ## Importing Our List of App Market ID

# %%
stocks = pd.read_csv('App-Ads.txt for Top Account - Owner.csv')

# %% [markdown]
# ## Adding columns to a Pandas DataFrame

# %%
domainID=stocks['domain']
my_columns = ['domainID', 'i']

# %% [markdown]
# ##  Looping Through The MarketID in Our List of CSV

# %%
final_dataframe = pd.DataFrame(columns = my_columns)

for domainID in stocks['domain']:
    txturl = f'http://{domainID}/app-ads.txt'
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    try:
        response = requests.get(txturl, headers=headers)  

        response.raise_for_status()
    except Exception as err:

        final_dataframe = final_dataframe.append(
                            pd.Series([
                                        domainID,
                                        'HTTPError',],
                                        index = my_columns), 
                                        ignore_index = True)
    else:
        response=response.text
        lowerResponse=response.lower()
        i = 0
        if 'vungle' not in lowerResponse: i=i+1
        if 'acexchange.co.kr, 1017355401' not in lowerResponse and 'acexchange.co.kr,1017355401' not in lowerResponse: i=i+1
        if 'acexchange.co.kr, 1081983882' not in lowerResponse and 'acexchange.co.kr,1081983882' not in lowerResponse: i=i+1
        if 'acexchange.co.kr, 1618149085' not in lowerResponse and 'acexchange.co.kr,1618149085' not in lowerResponse: i=i+1
        if 'adcolony.com, 197af3936679d34e' not in lowerResponse and 'adcolony.com,197af3936679d34e' not in lowerResponse: i=i+1
        if 'adcolony.com, 1efc6603710003ea' not in lowerResponse and 'adcolony.com,1efc6603710003ea' not in lowerResponse: i=i+1
        if 'adcolony.com, 1efc6603710003ea' not in lowerResponse and 'adcolony.com,1efc6603710003ea' not in lowerResponse: i=i+1
        if 'adcolony.com, 382d79cd1387e603' not in lowerResponse and 'adcolony.com,382d79cd1387e603' not in lowerResponse: i=i+1
        if 'adcolony.com, 382d79cd1387e603' not in lowerResponse and 'adcolony.com,382d79cd1387e603' not in lowerResponse: i=i+1
        if 'adcolony.com, 7d04a18a58085918' not in lowerResponse and 'adcolony.com,7d04a18a58085918' not in lowerResponse: i=i+1
        if 'adcolony.com, 801e49d1be83b5f9' not in lowerResponse and 'adcolony.com,801e49d1be83b5f9' not in lowerResponse: i=i+1
        if 'adcolony.com, 801e49d1be83b5f9' not in lowerResponse and 'adcolony.com,801e49d1be83b5f9' not in lowerResponse: i=i+1
        if 'adcolony.com, 81685aa581edd381' not in lowerResponse and 'adcolony.com,81685aa581edd381' not in lowerResponse: i=i+1
        if 'adcolony.com, c490f6e7399a25d6' not in lowerResponse and 'adcolony.com,c490f6e7399a25d6' not in lowerResponse: i=i+1
        if 'adcolony.com, e8d70ef9dfabde92' not in lowerResponse and 'adcolony.com,e8d70ef9dfabde92' not in lowerResponse: i=i+1
        if 'adcolony.com, f858ba060bce51ad' not in lowerResponse and 'adcolony.com,f858ba060bce51ad' not in lowerResponse: i=i+1
        if 'admanmedia.com, 43' not in lowerResponse and 'admanmedia.com,43' not in lowerResponse: i=i+1
        if 'admanmedia.com, 48' not in lowerResponse and 'admanmedia.com,48' not in lowerResponse: i=i+1
        if 'admanmedia.com, 48' not in lowerResponse and 'admanmedia.com,48' not in lowerResponse: i=i+1
        if 'admanmedia.com, 594' not in lowerResponse and 'admanmedia.com,594' not in lowerResponse: i=i+1
        if 'admanmedia.com, 594' not in lowerResponse and 'admanmedia.com,594' not in lowerResponse: i=i+1
        if 'admixer.co.kr, 1185' not in lowerResponse and 'admixer.co.kr,1185' not in lowerResponse: i=i+1
        if 'admixer.co.kr, 1287' not in lowerResponse and 'admixer.co.kr,1287' not in lowerResponse: i=i+1
        if 'admixer.co.kr, 1287' not in lowerResponse and 'admixer.co.kr,1287' not in lowerResponse: i=i+1
        if 'admixer.com, 8676470' not in lowerResponse and 'admixer.com,8676470' not in lowerResponse: i=i+1
        if 'admixer.net, 0072fb58-999b-445e-9a9b-3fc2a7194277' not in lowerResponse and 'admixer.net,0072fb58-999b-445e-9a9b-3fc2a7194277' not in lowerResponse: i=i+1
        if 'admixer.net, 2878f07c-cc3f-4f8a-a26c-8e6033a539a6' not in lowerResponse and 'admixer.net,2878f07c-cc3f-4f8a-a26c-8e6033a539a6' not in lowerResponse: i=i+1
        if 'admixer.net, 3d2ed9f3-1ce6-436c-896b-4d9c8418ad3f' not in lowerResponse and 'admixer.net,3d2ed9f3-1ce6-436c-896b-4d9c8418ad3f' not in lowerResponse: i=i+1
        if 'admixer.net, 8e380da6-31ba-488c-939c-290c48d577e4' not in lowerResponse and 'admixer.net,8e380da6-31ba-488c-939c-290c48d577e4' not in lowerResponse: i=i+1
        if 'admixer.net, de2ae535-59eb-4f0b-95e3-89f821933d47' not in lowerResponse and 'admixer.net,de2ae535-59eb-4f0b-95e3-89f821933d47' not in lowerResponse: i=i+1
        if 'admixer.net, de2ae535-59eb-4f0b-95e3-89f821933d47' not in lowerResponse and 'admixer.net,de2ae535-59eb-4f0b-95e3-89f821933d47' not in lowerResponse: i=i+1
        if 'adtiming.com, a-126' not in lowerResponse and 'adtiming.com,a-126' not in lowerResponse: i=i+1
        if 'advertising.com, 25990' not in lowerResponse and 'advertising.com,25990' not in lowerResponse: i=i+1
        if 'advertising.com, 28246' not in lowerResponse and 'advertising.com,28246' not in lowerResponse: i=i+1
        if 'advertising.com, 28246' not in lowerResponse and 'advertising.com,28246' not in lowerResponse: i=i+1
        if 'advertising.com, 6814' not in lowerResponse and 'advertising.com,6814' not in lowerResponse: i=i+1
        if 'adview.com, 32076181' not in lowerResponse and 'adview.com,32076181' not in lowerResponse: i=i+1
        if 'adview.com, 32076181' not in lowerResponse and 'adview.com,32076181' not in lowerResponse: i=i+1
        if 'adwmg.com, 8676470' not in lowerResponse and 'adwmg.com,8676470' not in lowerResponse: i=i+1
        if 'adyoulike.com, b4bf4fdd9b0b915f746f6747ff432bde' not in lowerResponse and 'adyoulike.com,b4bf4fdd9b0b915f746f6747ff432bde' not in lowerResponse: i=i+1
        if 'algorix.co, 54250' not in lowerResponse and 'algorix.co,54250' not in lowerResponse: i=i+1
        if 'aol.com, 57992' not in lowerResponse and 'aol.com,57992' not in lowerResponse: i=i+1
        if 'aol.com, 58905' not in lowerResponse and 'aol.com,58905' not in lowerResponse: i=i+1
        if 'aol.com, 59025' not in lowerResponse and 'aol.com,59025' not in lowerResponse: i=i+1
        if 'appads.in, 107606' not in lowerResponse and 'appads.in,107606' not in lowerResponse: i=i+1
        if 'appnexus.com, 10005' not in lowerResponse and 'appnexus.com,10005' not in lowerResponse: i=i+1
        if 'appnexus.com, 10128' not in lowerResponse and 'appnexus.com,10128' not in lowerResponse: i=i+1
        if 'appnexus.com, 10824' not in lowerResponse and 'appnexus.com,10824' not in lowerResponse: i=i+1
        if 'appnexus.com, 11452' not in lowerResponse and 'appnexus.com,11452' not in lowerResponse: i=i+1
        if 'appnexus.com, 12223' not in lowerResponse and 'appnexus.com,12223' not in lowerResponse: i=i+1
        if 'appnexus.com, 13099' not in lowerResponse and 'appnexus.com,13099' not in lowerResponse: i=i+1
        if 'appnexus.com, 3368' not in lowerResponse and 'appnexus.com,3368' not in lowerResponse: i=i+1
        if 'appnexus.com, 3703' not in lowerResponse and 'appnexus.com,3703' not in lowerResponse: i=i+1
        if 'appnexus.com, 3703' not in lowerResponse and 'appnexus.com,3703' not in lowerResponse: i=i+1
        if 'appnexus.com, 4052' not in lowerResponse and 'appnexus.com,4052' not in lowerResponse: i=i+1
        if 'appnexus.com, 4052' not in lowerResponse and 'appnexus.com,4052' not in lowerResponse: i=i+1
        if 'appnexus.com, 8178' not in lowerResponse and 'appnexus.com,8178' not in lowerResponse: i=i+1
        if 'appnexus.com, 8217' not in lowerResponse and 'appnexus.com,8217' not in lowerResponse: i=i+1
        if 'appnexus.com, 9569' not in lowerResponse and 'appnexus.com,9569' not in lowerResponse: i=i+1
        if 'appnexus.com, 9569' not in lowerResponse and 'appnexus.com,9569' not in lowerResponse: i=i+1
        if 'aralego.com, par-2736764b3a38eb77fdeaeb7444ab844' not in lowerResponse and 'aralego.com,par-2736764b3a38eb77fdeaeb7444ab844' not in lowerResponse: i=i+1
        if 'aralego.com, par-8a2a4a443b29bb92f9622d3a67346ab' not in lowerResponse and 'aralego.com,par-8a2a4a443b29bb92f9622d3a67346ab' not in lowerResponse: i=i+1
        if 'aralego.com, par-be776b39322a364bc7767a69ab99bbd9' not in lowerResponse and 'aralego.com,par-be776b39322a364bc7767a69ab99bbd9' not in lowerResponse: i=i+1
        if 'aralego.com, par-d232d76a227923da1d28d94aa9699ae8' not in lowerResponse and 'aralego.com,par-d232d76a227923da1d28d94aa9699ae8' not in lowerResponse: i=i+1
        if 'aralego.com, par-d233672dd744287dcd7e2439b82494ad' not in lowerResponse and 'aralego.com,par-d233672dd744287dcd7e2439b82494ad' not in lowerResponse: i=i+1
        if 'aralego.com, pub-77229e766e887de6fb9ed63a78d6a629' not in lowerResponse and 'aralego.com,pub-77229e766e887de6fb9ed63a78d6a629' not in lowerResponse: i=i+1
        if 'axonix.com, 56222' not in lowerResponse and 'axonix.com,56222' not in lowerResponse: i=i+1
        if 'axonix.com, 56222' not in lowerResponse and 'axonix.com,56222' not in lowerResponse: i=i+1
        if 'axonix.com, 57264' not in lowerResponse and 'axonix.com,57264' not in lowerResponse: i=i+1
        if 'axonix.com, 57716' not in lowerResponse and 'axonix.com,57716' not in lowerResponse: i=i+1
        if 'axonix.com, 57869' not in lowerResponse and 'axonix.com,57869' not in lowerResponse: i=i+1
        if 'beachfront.com, 805' not in lowerResponse and 'beachfront.com,805' not in lowerResponse: i=i+1
        if 'betweendigital.com, 43092' not in lowerResponse and 'betweendigital.com,43092' not in lowerResponse: i=i+1
        if 'betweendigital.com, 43092' not in lowerResponse and 'betweendigital.com,43092' not in lowerResponse: i=i+1
        if 'betweendigital.com, 43843' not in lowerResponse and 'betweendigital.com,43843' not in lowerResponse: i=i+1
        if 'bidence.com, 3de04db04d6eb28b13281a39b1c16d67' not in lowerResponse and 'bidence.com,3de04db04d6eb28b13281a39b1c16d67' not in lowerResponse: i=i+1
        if 'bidmachine.io, 55' not in lowerResponse and 'bidmachine.io,55' not in lowerResponse: i=i+1
        if 'bidmachine.io, 59' not in lowerResponse and 'bidmachine.io,59' not in lowerResponse: i=i+1
        if 'blis.com, 33' not in lowerResponse and 'blis.com,33' not in lowerResponse: i=i+1
        if 'chartboost.com, 5eac93f341016b09ff0019b6' not in lowerResponse and 'chartboost.com,5eac93f341016b09ff0019b6' not in lowerResponse: i=i+1
        if 'cmcm.com, 105' not in lowerResponse and 'cmcm.com,105' not in lowerResponse: i=i+1
        if 'cmcm.com, 127' not in lowerResponse and 'cmcm.com,127' not in lowerResponse: i=i+1
        if 'cmcm.com, 135' not in lowerResponse and 'cmcm.com,135' not in lowerResponse: i=i+1
        if 'cmcm.com, 271' not in lowerResponse and 'cmcm.com,271' not in lowerResponse: i=i+1
        if 'contextweb.com, 560288' not in lowerResponse and 'contextweb.com,560288' not in lowerResponse: i=i+1
        if 'contextweb.com, 561849' not in lowerResponse and 'contextweb.com,561849' not in lowerResponse: i=i+1
        if 'contextweb.com, 561884' not in lowerResponse and 'contextweb.com,561884' not in lowerResponse: i=i+1
        if 'contextweb.com, 561913' not in lowerResponse and 'contextweb.com,561913' not in lowerResponse: i=i+1
        if 'contextweb.com, 561998' not in lowerResponse and 'contextweb.com,561998' not in lowerResponse: i=i+1
        if 'contextweb.com, 562122' not in lowerResponse and 'contextweb.com,562122' not in lowerResponse: i=i+1
        if 'contextweb.com, 562122' not in lowerResponse and 'contextweb.com,562122' not in lowerResponse: i=i+1
        if 'conversantmedia.com, 100081' not in lowerResponse and 'conversantmedia.com,100081' not in lowerResponse: i=i+1
        if 'conversantmedia.com, 100081' not in lowerResponse and 'conversantmedia.com,100081' not in lowerResponse: i=i+1
        if 'conversantmedia.com, 100246' not in lowerResponse and 'conversantmedia.com,100246' not in lowerResponse: i=i+1
        if 'conversantmedia.com, 100293' not in lowerResponse and 'conversantmedia.com,100293' not in lowerResponse: i=i+1
        if 'conversantmedia.com, 40881' not in lowerResponse and 'conversantmedia.com,40881' not in lowerResponse: i=i+1
        if 'criteo.com, 186227' not in lowerResponse and 'criteo.com,186227' not in lowerResponse: i=i+1
        if 'decenterads.com, 14' not in lowerResponse and 'decenterads.com,14' not in lowerResponse: i=i+1
        if 'decenterads.com, 14' not in lowerResponse and 'decenterads.com,14' not in lowerResponse: i=i+1
        if 'decenterads.com, 198' not in lowerResponse and 'decenterads.com,198' not in lowerResponse: i=i+1
        if 'decenterads.com, 92' not in lowerResponse and 'decenterads.com,92' not in lowerResponse: i=i+1
        if 'districtm.io, 101649' not in lowerResponse and 'districtm.io,101649' not in lowerResponse: i=i+1
        if 'e-planning.net, 2af6560b926d20f9' not in lowerResponse and 'e-planning.net,2af6560b926d20f9' not in lowerResponse: i=i+1
        if 'e-planning.net, a15ce31379a418ac' not in lowerResponse and 'e-planning.net,a15ce31379a418ac' not in lowerResponse: i=i+1
        if 'emxdgt.com, 1324' not in lowerResponse and 'emxdgt.com,1324' not in lowerResponse: i=i+1
        if 'engagebdr.com, 10181' not in lowerResponse and 'engagebdr.com,10181' not in lowerResponse: i=i+1
        if 'engagebdr.com, 10252' not in lowerResponse and 'engagebdr.com,10252' not in lowerResponse: i=i+1
        if 'engagebdr.com, 16' not in lowerResponse and 'engagebdr.com,16' not in lowerResponse: i=i+1
        if 'engagebdr.com, 7' not in lowerResponse and 'engagebdr.com,7' not in lowerResponse: i=i+1
        if 'engagebdr.com, 84' not in lowerResponse and 'engagebdr.com,84' not in lowerResponse: i=i+1
        if 'flat-ads.com, 6' not in lowerResponse and 'flat-ads.com,6' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1058753' not in lowerResponse and 'freewheel.tv,1058753' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1058769' not in lowerResponse and 'freewheel.tv,1058769' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1161393' not in lowerResponse and 'freewheel.tv,1161393' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1162449' not in lowerResponse and 'freewheel.tv,1162449' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1173729' not in lowerResponse and 'freewheel.tv,1173729' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1173793' not in lowerResponse and 'freewheel.tv,1173793' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1192767' not in lowerResponse and 'freewheel.tv,1192767' not in lowerResponse: i=i+1
        if 'freewheel.tv, 1192799' not in lowerResponse and 'freewheel.tv,1192799' not in lowerResponse: i=i+1
        if 'freewheel.tv, 20393' not in lowerResponse and 'freewheel.tv,20393' not in lowerResponse: i=i+1
        if 'freewheel.tv, 24377' not in lowerResponse and 'freewheel.tv,24377' not in lowerResponse: i=i+1
        if 'gammassp.com, 1521707344' not in lowerResponse and 'gammassp.com,1521707344' not in lowerResponse: i=i+1
        if 'gitberry.com, xlv' not in lowerResponse and 'gitberry.com,xlv' not in lowerResponse: i=i+1
        if 'google.com, pub-3769010358500643' not in lowerResponse and 'google.com,pub-3769010358500643' not in lowerResponse: i=i+1
        if 'google.com, pub-4568609371004228' not in lowerResponse and 'google.com,pub-4568609371004228' not in lowerResponse: i=i+1
        if 'google.com, pub-7214269347534569' not in lowerResponse and 'google.com,pub-7214269347534569' not in lowerResponse: i=i+1
        if 'google.com, pub-9685734445476814' not in lowerResponse and 'google.com,pub-9685734445476814' not in lowerResponse: i=i+1
        if 'gothamads.com, 1339' not in lowerResponse and 'gothamads.com,1339' not in lowerResponse: i=i+1
        if 'groundtruth.com, 107' not in lowerResponse and 'groundtruth.com,107' not in lowerResponse: i=i+1
        if 'groundtruth.com, 107' not in lowerResponse and 'groundtruth.com,107' not in lowerResponse: i=i+1
        if 'gumgum.com, 13706' not in lowerResponse and 'gumgum.com,13706' not in lowerResponse: i=i+1
        if 'hitapps.com, 8613985ec49eb8f757ae6439e879bb2a6784' not in lowerResponse and 'hitapps.com,8613985ec49eb8f757ae6439e879bb2a6784' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1210' not in lowerResponse and 'improvedigital.com,1210' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1221' not in lowerResponse and 'improvedigital.com,1221' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1331' not in lowerResponse and 'improvedigital.com,1331' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1331' not in lowerResponse and 'improvedigital.com,1331' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1366' not in lowerResponse and 'improvedigital.com,1366' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1532' not in lowerResponse and 'improvedigital.com,1532' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1532' not in lowerResponse and 'improvedigital.com,1532' not in lowerResponse: i=i+1
        if 'improvedigital.com, 1556' not in lowerResponse and 'improvedigital.com,1556' not in lowerResponse: i=i+1
        if 'indexexchange.com, 184738' not in lowerResponse and 'indexexchange.com,184738' not in lowerResponse: i=i+1
        if 'indexexchange.com, 185578' not in lowerResponse and 'indexexchange.com,185578' not in lowerResponse: i=i+1
        if 'indexexchange.com, 185774' not in lowerResponse and 'indexexchange.com,185774' not in lowerResponse: i=i+1
        if 'indexexchange.com, 191332' not in lowerResponse and 'indexexchange.com,191332' not in lowerResponse: i=i+1
        if 'indexexchange.com, 191332' not in lowerResponse and 'indexexchange.com,191332' not in lowerResponse: i=i+1
        if 'indexexchange.com, 194730' not in lowerResponse and 'indexexchange.com,194730' not in lowerResponse: i=i+1
        if 'inmobi.com, 22e5354e453f49348325184e25464adb' not in lowerResponse and 'inmobi.com,22e5354e453f49348325184e25464adb' not in lowerResponse: i=i+1
        if 'inmobi.com, 5baa7ca93ef847c0876297e737dac3ee' not in lowerResponse and 'inmobi.com,5baa7ca93ef847c0876297e737dac3ee' not in lowerResponse: i=i+1
        if 'inmobi.com, 61d733c3779d43e590c51c8bc078e10c' not in lowerResponse and 'inmobi.com,61d733c3779d43e590c51c8bc078e10c' not in lowerResponse: i=i+1
        if 'inmobi.com, 867c89bb53994aaeb9dae3ce75b03e78' not in lowerResponse and 'inmobi.com,867c89bb53994aaeb9dae3ce75b03e78' not in lowerResponse: i=i+1
        if 'inmobi.com, 867c89bb53994aaeb9dae3ce75b03e78' not in lowerResponse and 'inmobi.com,867c89bb53994aaeb9dae3ce75b03e78' not in lowerResponse: i=i+1
        if 'inmobi.com, ab915bcef5b24940bf745f1a8f427bec' not in lowerResponse and 'inmobi.com,ab915bcef5b24940bf745f1a8f427bec' not in lowerResponse: i=i+1
        if 'inmobi.com, c1e6d3502da64ebaa3ad0e4a4be15f11' not in lowerResponse and 'inmobi.com,c1e6d3502da64ebaa3ad0e4a4be15f11' not in lowerResponse: i=i+1
        if 'inmobi.com, ec6f6ceb8bb1440ba5455644ec96c275' not in lowerResponse and 'inmobi.com,ec6f6ceb8bb1440ba5455644ec96c275' not in lowerResponse: i=i+1
        if 'inmobi.com, f3924290136e4129a5c082ff982c3a58' not in lowerResponse and 'inmobi.com,f3924290136e4129a5c082ff982c3a58' not in lowerResponse: i=i+1
        if 'kubient.com, 5eb2cb089c866' not in lowerResponse and 'kubient.com,5eb2cb089c866' not in lowerResponse: i=i+1
        if 'lijit.com, 273644' not in lowerResponse and 'lijit.com,273644' not in lowerResponse: i=i+1
        if 'limpid.tv, 203581' not in lowerResponse and 'limpid.tv,203581' not in lowerResponse: i=i+1
        if 'lkqd.net, 459' not in lowerResponse and 'lkqd.net,459' not in lowerResponse: i=i+1
        if 'lkqd.net, 647' not in lowerResponse and 'lkqd.net,647' not in lowerResponse: i=i+1
        if 'lkqd.net, 654' not in lowerResponse and 'lkqd.net,654' not in lowerResponse: i=i+1
        if 'loopme.com, 10178' not in lowerResponse and 'loopme.com,10178' not in lowerResponse: i=i+1
        if 'loopme.com, 10178' not in lowerResponse and 'loopme.com,10178' not in lowerResponse: i=i+1
        if 'loopme.com, 10999' not in lowerResponse and 'loopme.com,10999' not in lowerResponse: i=i+1
        if 'loopme.com, 11189' not in lowerResponse and 'loopme.com,11189' not in lowerResponse: i=i+1
        if 'loopme.com, 11278' not in lowerResponse and 'loopme.com,11278' not in lowerResponse: i=i+1
        if 'loopme.com, 11281' not in lowerResponse and 'loopme.com,11281' not in lowerResponse: i=i+1
        if 'loopme.com, 11296' not in lowerResponse and 'loopme.com,11296' not in lowerResponse: i=i+1
        if 'loopme.com, 11322' not in lowerResponse and 'loopme.com,11322' not in lowerResponse: i=i+1
        if 'loopme.com, 5679' not in lowerResponse and 'loopme.com,5679' not in lowerResponse: i=i+1
        if 'loopme.com, 9724' not in lowerResponse and 'loopme.com,9724' not in lowerResponse: i=i+1
        if 'loopme.com, s-2411' not in lowerResponse and 'loopme.com,s-2411' not in lowerResponse: i=i+1
        if 'mars.media, 1010422' not in lowerResponse and 'mars.media,1010422' not in lowerResponse: i=i+1
        if 'mars.media, 102753' not in lowerResponse and 'mars.media,102753' not in lowerResponse: i=i+1
        if 'mars.media, 102753' not in lowerResponse and 'mars.media,102753' not in lowerResponse: i=i+1
        if 'meitu.com, 149' not in lowerResponse and 'meitu.com,149' not in lowerResponse: i=i+1
        if 'meitu.com, 179' not in lowerResponse and 'meitu.com,179' not in lowerResponse: i=i+1
        if 'meitu.com, 253' not in lowerResponse and 'meitu.com,253' not in lowerResponse: i=i+1
        if 'mobfox.com, 82593' not in lowerResponse and 'mobfox.com,82593' not in lowerResponse: i=i+1
        if 'mobirtb.com, 149' not in lowerResponse and 'mobirtb.com,149' not in lowerResponse: i=i+1
        if 'olaex.biz, 100023' not in lowerResponse and 'olaex.biz,100023' not in lowerResponse: i=i+1
        if 'onetag.com, 59aa7be4921bac8' not in lowerResponse and 'onetag.com,59aa7be4921bac8' not in lowerResponse: i=i+1
        if 'onetag.com, 59aa7be4921bac8' not in lowerResponse and 'onetag.com,59aa7be4921bac8' not in lowerResponse: i=i+1
        if 'onetag.com, 59d216e971852f2' not in lowerResponse and 'onetag.com,59d216e971852f2' not in lowerResponse: i=i+1
        if 'onetag.com, 5a02ff98ba6be67' not in lowerResponse and 'onetag.com,5a02ff98ba6be67' not in lowerResponse: i=i+1
        if 'onetag.com, 5d1628750185ace' not in lowerResponse and 'onetag.com,5d1628750185ace' not in lowerResponse: i=i+1
        if 'onetag.com, 66cff8e37d871be' not in lowerResponse and 'onetag.com,66cff8e37d871be' not in lowerResponse: i=i+1
        if 'onetag.com, 74ea58ae86fd4b0' not in lowerResponse and 'onetag.com,74ea58ae86fd4b0' not in lowerResponse: i=i+1
        if 'openx.com, 537149888' not in lowerResponse and 'openx.com,537149888' not in lowerResponse: i=i+1
        if 'openx.com, 537152826' not in lowerResponse and 'openx.com,537152826' not in lowerResponse: i=i+1
        if 'openx.com, 539315083' not in lowerResponse and 'openx.com,539315083' not in lowerResponse: i=i+1
        if 'openx.com, 539472296' not in lowerResponse and 'openx.com,539472296' not in lowerResponse: i=i+1
        if 'openx.com, 540011801' not in lowerResponse and 'openx.com,540011801' not in lowerResponse: i=i+1
        if 'openx.com, 540031703' not in lowerResponse and 'openx.com,540031703' not in lowerResponse: i=i+1
        if 'openx.com, 540280728' not in lowerResponse and 'openx.com,540280728' not in lowerResponse: i=i+1
        if 'openx.com, 540298543' not in lowerResponse and 'openx.com,540298543' not in lowerResponse: i=i+1
        if 'openx.com, 540298543' not in lowerResponse and 'openx.com,540298543' not in lowerResponse: i=i+1
        if 'openx.com, 540326226' not in lowerResponse and 'openx.com,540326226' not in lowerResponse: i=i+1
        if 'openx.com, 540326226' not in lowerResponse and 'openx.com,540326226' not in lowerResponse: i=i+1
        if 'openx.com, 540543195' not in lowerResponse and 'openx.com,540543195' not in lowerResponse: i=i+1
        if 'openx.com, 540679900' not in lowerResponse and 'openx.com,540679900' not in lowerResponse: i=i+1
        if 'openx.com, 540679900' not in lowerResponse and 'openx.com,540679900' not in lowerResponse: i=i+1
        if 'openx.com, 541031350' not in lowerResponse and 'openx.com,541031350' not in lowerResponse: i=i+1
        if 'openx.com, 541177349' not in lowerResponse and 'openx.com,541177349' not in lowerResponse: i=i+1
        if 'pokkt.com, 5610' not in lowerResponse and 'pokkt.com,5610' not in lowerResponse: i=i+1
        if 'pokkt.com, 7000' not in lowerResponse and 'pokkt.com,7000' not in lowerResponse: i=i+1
        if 'pokkt.com, 7606' not in lowerResponse and 'pokkt.com,7606' not in lowerResponse: i=i+1
        if 'pokkt.com, 7606' not in lowerResponse and 'pokkt.com,7606' not in lowerResponse: i=i+1
        if 'pubmatic.com, 155975' not in lowerResponse and 'pubmatic.com,155975' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156439' not in lowerResponse and 'pubmatic.com,156439' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156517' not in lowerResponse and 'pubmatic.com,156517' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156520' not in lowerResponse and 'pubmatic.com,156520' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156631' not in lowerResponse and 'pubmatic.com,156631' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156835' not in lowerResponse and 'pubmatic.com,156835' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156835' not in lowerResponse and 'pubmatic.com,156835' not in lowerResponse: i=i+1
        if 'pubmatic.com, 156931' not in lowerResponse and 'pubmatic.com,156931' not in lowerResponse: i=i+1
        if 'pubmatic.com, 157097' not in lowerResponse and 'pubmatic.com,157097' not in lowerResponse: i=i+1
        if 'pubmatic.com, 157654' not in lowerResponse and 'pubmatic.com,157654' not in lowerResponse: i=i+1
        if 'pubmatic.com, 158060' not in lowerResponse and 'pubmatic.com,158060' not in lowerResponse: i=i+1
        if 'pubmatic.com, 158100' not in lowerResponse and 'pubmatic.com,158100' not in lowerResponse: i=i+1
        if 'pubmatic.com, 158154' not in lowerResponse and 'pubmatic.com,158154' not in lowerResponse: i=i+1
        if 'pubmatic.com, 158154' not in lowerResponse and 'pubmatic.com,158154' not in lowerResponse: i=i+1
        if 'pubmatic.com, 158271' not in lowerResponse and 'pubmatic.com,158271' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159035' not in lowerResponse and 'pubmatic.com,159035' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159542' not in lowerResponse and 'pubmatic.com,159542' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159668' not in lowerResponse and 'pubmatic.com,159668' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159831' not in lowerResponse and 'pubmatic.com,159831' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159846' not in lowerResponse and 'pubmatic.com,159846' not in lowerResponse: i=i+1
        if 'pubmatic.com, 159897' not in lowerResponse and 'pubmatic.com,159897' not in lowerResponse: i=i+1
        if 'pubmatic.com, 160145' not in lowerResponse and 'pubmatic.com,160145' not in lowerResponse: i=i+1
        if 'pubmatic.com, 160194' not in lowerResponse and 'pubmatic.com,160194' not in lowerResponse: i=i+1
        if 'pubmatic.com, 160195' not in lowerResponse and 'pubmatic.com,160195' not in lowerResponse: i=i+1
        if 'pubmatic.com, 8676470' not in lowerResponse and 'pubmatic.com,8676470' not in lowerResponse: i=i+1
        if 'pubmatic.com, 92509' not in lowerResponse and 'pubmatic.com,92509' not in lowerResponse: i=i+1
        if 'pubnative.net, 1006458' not in lowerResponse and 'pubnative.net,1006458' not in lowerResponse: i=i+1
        if 'pubnative.net, 1006576' not in lowerResponse and 'pubnative.net,1006576' not in lowerResponse: i=i+1
        if 'pubnative.net, 1006936' not in lowerResponse and 'pubnative.net,1006936' not in lowerResponse: i=i+1
        if 'pubnative.net, 1006936' not in lowerResponse and 'pubnative.net,1006936' not in lowerResponse: i=i+1
        if 'pubnative.net, 1006951' not in lowerResponse and 'pubnative.net,1006951' not in lowerResponse: i=i+1
        if 'pubnative.net, 1007302' not in lowerResponse and 'pubnative.net,1007302' not in lowerResponse: i=i+1
        if 'pubwheel.com, 32076181' not in lowerResponse and 'pubwheel.com,32076181' not in lowerResponse: i=i+1
        if 'reforge.in, 353' not in lowerResponse and 'reforge.in,353' not in lowerResponse: i=i+1
        if 'rhythmone.com, 188404962' not in lowerResponse and 'rhythmone.com,188404962' not in lowerResponse: i=i+1
        if 'rhythmone.com, 2564526802' not in lowerResponse and 'rhythmone.com,2564526802' not in lowerResponse: i=i+1
        if 'rhythmone.com, 3218195319' not in lowerResponse and 'rhythmone.com,3218195319' not in lowerResponse: i=i+1
        if 'rhythmone.com, 3218195319' not in lowerResponse and 'rhythmone.com,3218195319' not in lowerResponse: i=i+1
        if 'rhythmone.com, 3880497124' not in lowerResponse and 'rhythmone.com,3880497124' not in lowerResponse: i=i+1
        if 'rhythmone.com, 4173858586' not in lowerResponse and 'rhythmone.com,4173858586' not in lowerResponse: i=i+1
        if 'rhythmone.com, 4173858586' not in lowerResponse and 'rhythmone.com,4173858586' not in lowerResponse: i=i+1
        if 'rhythmone.com, 4268206200' not in lowerResponse and 'rhythmone.com,4268206200' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 11726' not in lowerResponse and 'rubiconproject.com,11726' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 11726' not in lowerResponse and 'rubiconproject.com,11726' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 12186' not in lowerResponse and 'rubiconproject.com,12186' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 12266' not in lowerResponse and 'rubiconproject.com,12266' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 12266' not in lowerResponse and 'rubiconproject.com,12266' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 13626' not in lowerResponse and 'rubiconproject.com,13626' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 13856' not in lowerResponse and 'rubiconproject.com,13856' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 13856' not in lowerResponse and 'rubiconproject.com,13856' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 15278' not in lowerResponse and 'rubiconproject.com,15278' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 16114' not in lowerResponse and 'rubiconproject.com,16114' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 16114' not in lowerResponse and 'rubiconproject.com,16114' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 16834' not in lowerResponse and 'rubiconproject.com,16834' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 17328' not in lowerResponse and 'rubiconproject.com,17328' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 17328' not in lowerResponse and 'rubiconproject.com,17328' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 19724' not in lowerResponse and 'rubiconproject.com,19724' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 19724' not in lowerResponse and 'rubiconproject.com,19724' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 20744' not in lowerResponse and 'rubiconproject.com,20744' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 20744' not in lowerResponse and 'rubiconproject.com,20744' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 23644' not in lowerResponse and 'rubiconproject.com,23644' not in lowerResponse: i=i+1
        if 'rubiconproject.com, 23732' not in lowerResponse and 'rubiconproject.com,23732' not in lowerResponse: i=i+1
        if 'sabio.us, 100032' not in lowerResponse and 'sabio.us,100032' not in lowerResponse: i=i+1
        if 'silvermob.com, 320' not in lowerResponse and 'silvermob.com,320' not in lowerResponse: i=i+1
        if 'smaato.com, 1100042823' not in lowerResponse and 'smaato.com,1100042823' not in lowerResponse: i=i+1
        if 'smaato.com, 1100044045' not in lowerResponse and 'smaato.com,1100044045' not in lowerResponse: i=i+1
        if 'smaato.com, 1100049757' not in lowerResponse and 'smaato.com,1100049757' not in lowerResponse: i=i+1
        if 'smartadserver.com, 1692' not in lowerResponse and 'smartadserver.com,1692' not in lowerResponse: i=i+1
        if 'smartadserver.com, 1692' not in lowerResponse and 'smartadserver.com,1692' not in lowerResponse: i=i+1
        if 'smartadserver.com, 3232' not in lowerResponse and 'smartadserver.com,3232' not in lowerResponse: i=i+1
        if 'smartadserver.com, 3797' not in lowerResponse and 'smartadserver.com,3797' not in lowerResponse: i=i+1
        if 'smartadserver.com, 3797' not in lowerResponse and 'smartadserver.com,3797' not in lowerResponse: i=i+1
        if 'smartadserver.com, 4071' not in lowerResponse and 'smartadserver.com,4071' not in lowerResponse: i=i+1
        if 'smartadserver.com, 4111' not in lowerResponse and 'smartadserver.com,4111' not in lowerResponse: i=i+1
        if 'smartyads.com, 368' not in lowerResponse and 'smartyads.com,368' not in lowerResponse: i=i+1
        if 'sonobi.com, cc3858f35e' not in lowerResponse and 'sonobi.com,cc3858f35e' not in lowerResponse: i=i+1
        if 'sonobi.com, eaec54c63f' not in lowerResponse and 'sonobi.com,eaec54c63f' not in lowerResponse: i=i+1
        if 'sonobi.com, eaec54c63f' not in lowerResponse and 'sonobi.com,eaec54c63f' not in lowerResponse: i=i+1
        if 'sovrn.com, 273644' not in lowerResponse and 'sovrn.com,273644' not in lowerResponse: i=i+1
        if 'spotx.tv, 117872' not in lowerResponse and 'spotx.tv,117872' not in lowerResponse: i=i+1
        if 'spotx.tv, 234183' not in lowerResponse and 'spotx.tv,234183' not in lowerResponse: i=i+1
        if 'spotx.tv, 283422' not in lowerResponse and 'spotx.tv,283422' not in lowerResponse: i=i+1
        if 'spotx.tv, 82068' not in lowerResponse and 'spotx.tv,82068' not in lowerResponse: i=i+1
        if 'spotx.tv, 99441' not in lowerResponse and 'spotx.tv,99441' not in lowerResponse: i=i+1
        if 'spotxchange.com, 117872' not in lowerResponse and 'spotxchange.com,117872' not in lowerResponse: i=i+1
        if 'spotxchange.com, 234183' not in lowerResponse and 'spotxchange.com,234183' not in lowerResponse: i=i+1
        if 'spotxchange.com, 283422' not in lowerResponse and 'spotxchange.com,283422' not in lowerResponse: i=i+1
        if 'spotxchange.com, 82068' not in lowerResponse and 'spotxchange.com,82068' not in lowerResponse: i=i+1
        if 'spotxchange.com, 99441' not in lowerResponse and 'spotxchange.com,99441' not in lowerResponse: i=i+1
        if 'tappx.com, 14039' not in lowerResponse and 'tappx.com,14039' not in lowerResponse: i=i+1
        if 'tappx.com, 14039' not in lowerResponse and 'tappx.com,14039' not in lowerResponse: i=i+1
        if 'target.my.com, 8676470' not in lowerResponse and 'target.my.com,8676470' not in lowerResponse: i=i+1
        if 'telaria.com, s92od-u4sw5' not in lowerResponse and 'telaria.com,s92od-u4sw5' not in lowerResponse: i=i+1
        if 'tpmn.io, 368' not in lowerResponse and 'tpmn.io,368' not in lowerResponse: i=i+1
        if 'tpmn.io, 406' not in lowerResponse and 'tpmn.io,406' not in lowerResponse: i=i+1
        if 'tremorhub.com, s92od-u4sw5' not in lowerResponse and 'tremorhub.com,s92od-u4sw5' not in lowerResponse: i=i+1
        if 'ucfunnel.com, par-8a2a4a443b29bb92f9622d3a67346ab' not in lowerResponse and 'ucfunnel.com,par-8a2a4a443b29bb92f9622d3a67346ab' not in lowerResponse: i=i+1
        if 'ucfunnel.com, par-be776b39322a364bc7767a69ab99bbd9' not in lowerResponse and 'ucfunnel.com,par-be776b39322a364bc7767a69ab99bbd9' not in lowerResponse: i=i+1
        if 'ucfunnel.com, par-d232d76a227923da1d28d94aa9699ae8' not in lowerResponse and 'ucfunnel.com,par-d232d76a227923da1d28d94aa9699ae8' not in lowerResponse: i=i+1
        if 'ucfunnel.com, par-d233672dd744287dcd7e2439b82494ad' not in lowerResponse and 'ucfunnel.com,par-d233672dd744287dcd7e2439b82494ad' not in lowerResponse: i=i+1
        if 'verve.com, 15290' not in lowerResponse and 'verve.com,15290' not in lowerResponse: i=i+1
        if 'verve.com, 15290' not in lowerResponse and 'verve.com,15290' not in lowerResponse: i=i+1
        if 'verve.com, 15503' not in lowerResponse and 'verve.com,15503' not in lowerResponse: i=i+1
        if 'verve.com, 15503' not in lowerResponse and 'verve.com,15503' not in lowerResponse: i=i+1
        if 'verve.com, 5897' not in lowerResponse and 'verve.com,5897' not in lowerResponse: i=i+1
        if 'video.unrulymedia.com, 3704396951' not in lowerResponse and 'video.unrulymedia.com,3704396951' not in lowerResponse: i=i+1
        if 'video.unrulymedia.com, 4268206200' not in lowerResponse and 'video.unrulymedia.com,4268206200' not in lowerResponse: i=i+1
        if 'webeyemob.com, 70090' not in lowerResponse and 'webeyemob.com,70090' not in lowerResponse: i=i+1
        if 'webeyemob.com, 70101' not in lowerResponse and 'webeyemob.com,70101' not in lowerResponse: i=i+1
        if 'xad.com, 958' not in lowerResponse and 'xad.com,958' not in lowerResponse: i=i+1
        if 'yahoo.com, 55771' not in lowerResponse and 'yahoo.com,55771' not in lowerResponse: i=i+1
        if 'yahoo.com, 57992' not in lowerResponse and 'yahoo.com,57992' not in lowerResponse: i=i+1
        if 'yahoo.com, 58905' not in lowerResponse and 'yahoo.com,58905' not in lowerResponse: i=i+1
        if 'yahoo.com, 59025' not in lowerResponse and 'yahoo.com,59025' not in lowerResponse: i=i+1
        if 'yieldlab.net, 2172218' not in lowerResponse and 'yieldlab.net,2172218' not in lowerResponse: i=i+1

        final_dataframe = final_dataframe.append(
                            pd.Series([
                                        domainID,
                                        i,],
                                        index = my_columns), 
                                        ignore_index = True)

    
final_dataframe
# Out:
#                      domainID          i
# 0             feelthemusi.com         41
# 1                  x-flow.app         51
# 2    microsoftcasualgames.com         66
# 3               peoplefun.com        204
# 4                  grindr.com        244
# ..                        ...        ...
# 474                       NaN  HTTPError
# 475                       NaN  HTTPError
# 476                       NaN  HTTPError
# 477            pivotgames.net        249
# 478    maxvideodownloader.com        240
#
# [479 rows x 2 columns]

# %% [markdown]
# ## pandas.DataFrame.to_csv

# %%
final_dataframe.to_csv('missing_check.csv')
