# %% [markdown]
# ## Library Imports

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## Importing Our List of App Market ID

# %%
stocks = pd.read_csv('Looker_MarketID_ios.csv')

# %%
marketID=stocks['marketid']

# %% [markdown]
# ## Adding columns to a Pandas DataFrame

# %%
my_columns = ['marketid', 'AppAdsUrl']

# %% [markdown]
# ##  Looping Through The MarketID in Our List of CSV
# 1. If dataJson[1] is not work, try dataJson[0]
# 2. Change platform iOS/Android before run

# %%
final_dataframe = pd.DataFrame(columns = my_columns)

for marketid in stocks['marketid']:
    api_url = f'http://api.adtimizer.co/ios/app-ads-txt?id={marketid}'
    data = requests.get(api_url)
    if data.status_code == 200:
        dataJson=data.json()
        final_dataframe = final_dataframe.append(
                            pd.Series([
                                        marketid,
                                        dataJson[0]['AppAdsUrl'],],
                                        index = my_columns), 
                                        ignore_index = True)

    elif data.status_code == 204:
       
        final_dataframe = final_dataframe.append(
                            pd.Series([
                                        marketid,
                                        data.status_code,],
                                        index = my_columns), 
                                        ignore_index = True)
    
final_dataframe
# Out:
#         marketid                                          AppAdsUrl
# 0   1.511642e+09                                     lionstudios.cc
# 1   1.135852e+09  6c6bb4516558c991fefc29021654f62d-store.api-all...
# 2   1.536131e+09                                      tap-nation.io
# 3   1.276081e+09                                   sumisumigame.com
# 4   1.487578e+09                               gamelinkedworld.info
# 5   1.504831e+09                                 app.picfuntech.com
# 6   1.134854e+09                                       pinkfong.com
# 7   1.509517e+09                                     unicostudio.co
# 8   5.713936e+08                                       gameloft.com
# 9   6.486682e+08                                    happywheels.com
# 10  1.462877e+09                                     111percent.net
# 11  1.535974e+09                                      amrita.studio
# 12  1.572797e+09                                              204.0
# 13  4.489991e+08                                              204.0
# 14  1.419735e+09                                              204.0
# 15  1.523245e+09                                     lionstudios.cc
# 16  1.401838e+09                                greenpandagames.com
# 17  1.483902e+09                                    playgendary.com
# 18  7.407371e+08                                         avakin.com
# 19  5.054463e+08                                        topface.com
# 20  1.492428e+09                                    triwingames.com
# 21  1.580546e+09                                   kolibrigames.com
# 22  9.794018e+08                            browserdocumentsapp.com
# 23  1.580397e+09                                        boombit.com
# 24  1.539409e+09                                      crazylabs.com
# 25  1.496612e+09                              vizor-interactive.com
# 26  1.481218e+09                                       cookapps.com
# 27  1.580100e+09                                    rollicgames.com
# 28  1.576806e+09                              sakuradreamworker.com
# 29  1.377372e+09                                      tastypill.com
# 30  1.575648e+09                                       mondayoff.me
# 31           NaN                                              204.0
# 32           NaN                                              204.0

# %% [markdown]
# ## pandas.DataFrame.to_csv

# %%
final_dataframe

# %%
final_dataframe.to_csv("ios.csv")
