# %%
import requests
import json

# %%
baseUrl='http://api.adtimizer.co/ios/app-ads-txt?id='
bundleName='591560124'
txt_url = baseUrl+bundleName

# %%
response = requests.get(txt_url, stream=True)
jsonResponse = response.json()
print(jsonResponse[1]['AppAdsUrl'])
# Out:
# feelthemusi.com

# %%
if "vungle" not in response.text:print("vungle.com, [yourVunglePublisherAccountID], DIRECT, c107d686becd2d77")
if 'publisherAccountId":"1efc6603710003ea' not in response.text: print("adcolony.com, 1efc6603710003ea, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"801e49d1be83b5f9' not in response.text: print("adcolony.com, 801e49d1be83b5f9, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"81685aa581edd381' not in response.text: print("adcolony.com, 81685aa581edd381, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"f858ba060bce51ad' not in response.text: print("adcolony.com, f858ba060bce51ad, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"594' not in response.text: print("admanmedia.com, 594, RESELLER")
if 'publisherAccountId":"8676470' not in response.text: print("admixer.com, 8676470, RESELLER")
if 'publisherAccountId":"2878f07c-cc3f-4f8a-a26c-8e6033a539a6' not in response.text: print("admixer.net, 2878f07c-cc3f-4f8a-a26c-8e6033a539a6, RESELLER")
if 'publisherAccountId":"3d2ed9f3-1ce6-436c-896b-4d9c8418ad3f' not in response.text: print("admixer.net, 3d2ed9f3-1ce6-436c-896b-4d9c8418ad3f, RESELLER")
if 'publisherAccountId":"8e380da6-31ba-488c-939c-290c48d577e4' not in response.text: print("admixer.net, 8e380da6-31ba-488c-939c-290c48d577e4, RESELLER")
if 'publisherAccountId":"a-126' not in response.text: print("adtiming.com, a-126, RESELLER, bf66753b8f380142")
if 'publisherAccountId":"25990' not in response.text: print("advertising.com, 25990, RESELLER")
if 'publisherAccountId":"28246' not in response.text: print("advertising.com, 28246, RESELLER")
if 'publisherAccountId":"8676470' not in response.text: print("adwmg.com, 8676470, RESELLER")
if 'publisherAccountId":"54250' not in response.text: print("algorix.co, 54250, RESELLER")
if 'publisherAccountId":"10128' not in response.text: print("appnexus.com, 10128, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"11452' not in response.text: print("appnexus.com, 11452, RESELLER")
if 'publisherAccountId":"3368' not in response.text: print("appnexus.com, 3368, RESELLER")
if 'publisherAccountId":"8178' not in response.text: print("appnexus.com, 8178, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"8217' not in response.text: print("appnexus.com, 8217, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"par-8A2A4A443B29BB92F9622D3A67346AB' not in response.text: print("aralego.com, par-8A2A4A443B29BB92F9622D3A67346AB, RESELLER")
if 'publisherAccountId":"par-D232D76A227923DA1D28D94AA9699AE8' not in response.text: print("aralego.com, par-D232D76A227923DA1D28D94AA9699AE8, RESELLER")
if 'publisherAccountId":"57869' not in response.text: print("axonix.com, 57869, RESELLER")
if 'publisherAccountId":"43092' not in response.text: print("betweendigital.com, 43092, RESELLER")
if 'publisherAccountId":"55' not in response.text: print("bidmachine.io, 55, RESELLER")
if 'publisherAccountId":"59' not in response.text: print("bidmachine.io, 59, RESELLER")
if 'publisherAccountId":"127' not in response.text: print("cmcm.com, 127, RESELLER")
if 'publisherAccountId":"271' not in response.text: print("cmcm.com, 271, RESELLER")
if 'publisherAccountId":"105' not in response.text: print("cmcm.com,105, RESELLER")
if 'publisherAccountId":"561849' not in response.text: print("contextweb.com, 561849, RESELLER, 89ff185a4c4e857c")
if 'publisherAccountId":"561884' not in response.text: print("contextweb.com, 561884, RESELLER, 89ff185a4c4e857c")
if 'publisherAccountId":"561913' not in response.text: print("contextweb.com, 561913, RESELLER, 89ff185a4c4e857c")
if 'publisherAccountId":"1324' not in response.text: print("EMXDGT.com, 1324, RESELLER, 1e1d41537f7cad7f")
if 'publisherAccountId":"10181' not in response.text: print("engagebdr.com, 10181, RESELLER")
if 'publisherAccountId":"10252' not in response.text: print("engagebdr.com, 10252, RESELLER")
if 'publisherAccountId":"16' not in response.text: print("engagebdr.com, 16, RESELLER")
if 'publisherAccountId":"7' not in response.text: print("engagebdr.com, 7, RESELLER")
if 'publisherAccountId":"84' not in response.text: print("engagebdr.com, 84, RESELLER")
if 'publisherAccountId":"1366' not in response.text: print("improvedigital.com, 1366, RESELLER")
if 'publisherAccountId":"1532' not in response.text: print("improvedigital.com, 1532, RESELLER")
if 'publisherAccountId":"185774' not in response.text: print("indexexchange.com, 185774, RESELLER, 50b1c356f2c5c8fc")
if 'publisherAccountId":"191332' not in response.text: print("indexexchange.com, 191332, RESELLER, 50b1c356f2c5c8fc")
if 'publisherAccountId":"22e5354e453f49348325184e25464adb' not in response.text: print("inmobi.com, 22e5354e453f49348325184e25464adb, RESELLER, 83e75a7ae333ca9d")
if 'publisherAccountId":"c1e6d3502da64ebaa3ad0e4a4be15f11' not in response.text: print("inmobi.com, c1e6d3502da64ebaa3ad0e4a4be15f11, RESELLER, 83e75a7ae333ca9d")
if 'publisherAccountId":"f3924290136e4129a5c082ff982c3a58' not in response.text: print("inmobi.com, f3924290136e4129a5c082ff982c3a58, RESELLER, 83e75a7ae333ca9d")
if 'publisherAccountId":"273644' not in response.text: print("lijit.com, 273644, RESELLER")
if 'publisherAccountId":"203581' not in response.text: print("Limpid.tv,203581,RESELLER")
if 'publisherAccountId":"10999' not in response.text: print("loopme.com, 10999, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"11278' not in response.text: print("loopme.com, 11278, RESELLER")
if 'publisherAccountId":"11296' not in response.text: print("loopme.com, 11296, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"149' not in response.text: print("meitu.com, 149, RESELLER")
if 'publisherAccountId":"179' not in response.text: print("meitu.com, 179, RESELLER")
if 'publisherAccountId":"253' not in response.text: print("meitu.com, 253, RESELLER")
if 'publisherAccountId":"59aa7be4921bac8' not in response.text: print("onetag.com, 59aa7be4921bac8, RESELLER")
if 'publisherAccountId":"59d216e971852f2' not in response.text: print("onetag.com, 59d216e971852f2, RESELLER")
if 'publisherAccountId":"5a02ff98ba6be67' not in response.text: print("onetag.com, 5a02ff98ba6be67, RESELLER")
if 'publisherAccountId":"5d1628750185ace' not in response.text: print("onetag.com, 5d1628750185ace, RESELLER")
if 'publisherAccountId":"537152826' not in response.text: print("openx.com, 537152826, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"539472296' not in response.text: print("openx.com, 539472296, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"540011801' not in response.text: print("openx.com, 540011801, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"540280728' not in response.text: print("openx.com, 540280728, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"540298543' not in response.text: print("openx.com, 540298543, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"540543195' not in response.text: print("openx.com, 540543195, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"540679900' not in response.text: print("openx.com, 540679900, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"541177349' not in response.text: print("openx.com, 541177349, RESELLER")
if 'publisherAccountId":"155975' not in response.text: print("pubmatic.com, 155975, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"156517' not in response.text: print("pubmatic.com, 156517, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"157654' not in response.text: print("pubmatic.com, 157654, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"158060' not in response.text: print("pubmatic.com, 158060, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"158154' not in response.text: print("pubmatic.com, 158154, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"159542' not in response.text: print("pubmatic.com, 159542, RESELLER")
if 'publisherAccountId":"159668' not in response.text: print("pubmatic.com, 159668, RESELLER")
if 'publisherAccountId":"159846' not in response.text: print("pubmatic.com, 159846, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"8676470' not in response.text: print("pubmatic.com, 8676470, RESELLER")
if 'publisherAccountId":"1006458' not in response.text: print("pubnative.net, 1006458, RESELLER, d641df8625486a7b")
if 'publisherAccountId":"1007302' not in response.text: print("pubnative.net, 1007302, RESELLER, d641df8625486a7b")
if 'publisherAccountId":"3880497124' not in response.text: print("rhythmone.com, 3880497124, RESELLER")
if 'publisherAccountId":"4173858586' not in response.text: print("rhythmone.com, 4173858586, RESELLER, a670c89d4a324e47")
if 'publisherAccountId":"13626' not in response.text: print("rubiconproject.com, 13626, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"15278' not in response.text: print("rubiconproject.com, 15278, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"17328' not in response.text: print("rubiconproject.com, 17328, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"19724' not in response.text: print("rubiconproject.com, 19724, RESELLER")
if 'publisherAccountId":"20744' not in response.text: print("rubiconproject.com, 20744, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"100032' not in response.text: print("sabio.us, 100032, RESELLER, 96ed93aaa9795702")
if 'publisherAccountId":"320' not in response.text: print("silvermob.com,320,RESELLER")
if 'publisherAccountId":"eaec54c63f' not in response.text: print("sonobi.com, eaec54c63f, RESELLER, d1a215d9eb5aee9e")
if 'publisherAccountId":"273644' not in response.text: print("sovrn.com, 273644, RESELLER")
if 'publisherAccountId":"234183' not in response.text: print("spotx.tv, 234183, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"99441' not in response.text: print("spotx.tv, 99441, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"234183' not in response.text: print("spotxchange.com, 234183, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"99441' not in response.text: print("spotxchange.com, 99441, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"8676470' not in response.text: print("target.my.com, 8676470, RESELLER")
if 'publisherAccountId":"par-8A2A4A443B29BB92F9622D3A67346AB' not in response.text: print("ucfunnel.com, par-8A2A4A443B29BB92F9622D3A67346AB, RESELLER")
if 'publisherAccountId":"par-D232D76A227923DA1D28D94AA9699AE8' not in response.text: print("ucfunnel.com, par-D232D76A227923DA1D28D94AA9699AE8, RESELLER")
if 'publisherAccountId":"15290' not in response.text: print("verve.com, 15290, RESELLER, 0c8f5958fc2d6270")
if 'publisherAccountId":"15503' not in response.text: print("verve.com, 15503, RESELLER, 0c8f5958fc2d6270")
if 'publisherAccountId":"3704396951' not in response.text: print("video.unrulymedia.com, 3704396951, RESELLER")
if 'publisherAccountId":"70090' not in response.text: print("webeyemob.com, 70090, RESELLER")
if 'publisherAccountId":"2172218' not in response.text: print("yieldlab.net, 2172218, RESELLER")
if 'publisherAccountId":"149' not in response.text: print("mobirtb.com, 149, RESELLER")
if 'publisherAccountId":"159831' not in response.text: print("pubmatic.com, 159831, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"159897' not in response.text: print("pubmatic.com, 159897, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"135' not in response.text: print("cmcm.com, 135, RESELLER")
if 'publisherAccountId":"539315083' not in response.text: print("openx.com, 539315083, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"186227' not in response.text: print("criteo.com, 186227, RESELLER")
if 'publisherAccountId":"4268206200' not in response.text: print("rhythmone.com, 4268206200, RESELLER, a670c89d4a324e47")
if 'publisherAccountId":"4268206200' not in response.text: print("video.unrulymedia.com,4268206200,RESELLER")
if 'publisherAccountId":"11281' not in response.text: print("loopme.com, 11281, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"100023' not in response.text: print("olaex.biz,100023,RESELLER")
if 'publisherAccountId":"158271' not in response.text: print("pubmatic.com, 158271, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"5eb2cb089c866' not in response.text: print("kubient.com, 5eb2cb089c866, RESELLER, 4f12311e6ed900a3")
if 'publisherAccountId":"5610' not in response.text: print("pokkt.com, 5610 , RESELLER, c45702d9311e25fd")
if 'publisherAccountId":"156520' not in response.text: print("pubmatic.com, 156520, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"117872' not in response.text: print("spotxchange.com, 117872, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"117872' not in response.text: print("spotx.tv, 117872, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"1058753' not in response.text: print("freewheel.tv, 1058753, RESELLER")
if 'publisherAccountId":"1058769' not in response.text: print("freewheel.tv, 1058769, RESELLER")
if 'publisherAccountId":"56222' not in response.text: print("axonix.com,56222,RESELLER")
if 'publisherAccountId":"12186' not in response.text: print("rubiconproject.com,12186,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"2af6560b926d20f9' not in response.text: print("e-planning.net,2af6560b926d20f9,RESELLER,c1ba615865ed87b2")
if 'publisherAccountId":"1556' not in response.text: print("improvedigital.com,1556,RESELLER")
if 'publisherAccountId":"541031350' not in response.text: print("openx.com,541031350,RESELLER,6a698e2ec38604c6")
if 'publisherAccountId":"156631' not in response.text: print("pubmatic.com,156631,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"32076181' not in response.text: print("adview.com, 32076181, RESELLER, 1b2cc038a11ea319")
if 'publisherAccountId":"32076181' not in response.text: print("pubwheel.com, 32076181, RESELLER, 1b2cc038a11ea319")
if 'publisherAccountId":"382d79cd1387e603' not in response.text: print("adcolony.com, 382d79cd1387e603, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"48' not in response.text: print("admanmedia.com, 48, RESELLER")
if 'publisherAccountId":"1287' not in response.text: print("admixer.co.kr, 1287, RESELLER")
if 'publisherAccountId":"0072fb58-999b-445e-9a9b-3fc2a7194277' not in response.text: print("admixer.net, 0072fb58-999b-445e-9a9b-3fc2a7194277, RESELLER")
if 'publisherAccountId":"de2ae535-59eb-4f0b-95e3-89f821933d47' not in response.text: print("admixer.net, de2ae535-59eb-4f0b-95e3-89f821933d47, RESELLER")
if 'publisherAccountId":"10005' not in response.text: print("appnexus.com, 10005, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"10824' not in response.text: print("appnexus.com, 10824, RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"9569' not in response.text: print("appnexus.com, 9569, RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"4052' not in response.text: print("appnexus.com, 4052, RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"3703' not in response.text: print("appnexus.com, 3703, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"par-BE776B39322A364BC7767A69AB99BBD9' not in response.text: print("aralego.com, par-BE776B39322A364BC7767A69AB99BBD9, RESELLER")
if 'publisherAccountId":"par-D233672DD744287DCD7E2439B82494AD' not in response.text: print("aralego.com, par-D233672DD744287DCD7E2439B82494AD, RESELLER")
if 'publisherAccountId":"5eac93f341016b09ff0019b6' not in response.text: print("chartboost.com, 5eac93f341016b09ff0019b6, RESELLER")
if 'publisherAccountId":"562122' not in response.text: print("contextweb.com, 562122, RESELLER, 89ff185a4c4e857c")
if 'publisherAccountId":"100081' not in response.text: print("conversantmedia.com, 100081, RESELLER, 03113cd04947736d")
if 'publisherAccountId":"14' not in response.text: print("decenterads.com, 14, RESELLER")
if 'publisherAccountId":"92' not in response.text: print("decenterads.com, 92, RESELLER")
if 'publisherAccountId":"101649' not in response.text: print("districtm.io,101649,RESELLER,3fd707be9c4527c3")
if 'publisherAccountId":"1521707344' not in response.text: print("gammassp.com, 1521707344, RESELLER, 31ac53fec2772a83")
if 'publisherAccountId":"pub-9685734445476814' not in response.text: print("google.com, pub-9685734445476814, RESELLER, f08c47fec0942fa0")
if 'publisherAccountId":"107' not in response.text: print("groundtruth.com, 107, RESELLER, 81cbf0a75a5e0e9a")
if 'publisherAccountId":"1331' not in response.text: print("improvedigital.com, 1331, RESELLER")
if 'publisherAccountId":"185578' not in response.text: print("indexexchange.com, 185578, RESELLER, 50b1c356f2c5c8fc")
if 'publisherAccountId":"867c89bb53994aaeb9dae3ce75b03e78' not in response.text: print("inmobi.com, 867c89bb53994aaeb9dae3ce75b03e78, RESELLER, 83e75a7ae333ca9d")
if 'publisherAccountId":"459' not in response.text: print("lkqd.net, 459, RESELLER, 59c49fa9598a0117")
if 'publisherAccountId":"11189' not in response.text: print("loopme.com, 11189, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"s-2411' not in response.text: print("loopme.com, s-2411, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"10178' not in response.text: print("loopme.com, 10178, RESELLER, 6c8d5f95897a5a3b")
if 'publisherAccountId":"102753' not in response.text: print("mars.media, 102753, RESELLER")
if 'publisherAccountId":"82593' not in response.text: print("mobfox.com, 82593, RESELLER, 5529a3d1f59865be")
if 'publisherAccountId":"540326226' not in response.text: print("openx.com, 540326226, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"16114' not in response.text: print("rubiconproject.com, 16114, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"7000' not in response.text: print("pokkt.com, 7000, RESELLER, c45702d9311e25fd")
if 'publisherAccountId":"156835' not in response.text: print("pubmatic.com, 156835, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"1006936' not in response.text: print("Pubnative.net, 1006936, RESELLER, d641df8625486a7b")
if 'publisherAccountId":"3218195319' not in response.text: print("rhythmone.com, 3218195319, RESELLER, a670c89d4a324e47")
if 'publisherAccountId":"13856' not in response.text: print("rubiconproject.com, 13856, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"16834' not in response.text: print("rubiconproject.com, 16834, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"11726' not in response.text: print("rubiconproject.com, 11726, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"12266' not in response.text: print("rubiconproject.com, 12266, RESELLER, 0bfd66d529a55807")
if 'publisherAccountId":"3797' not in response.text: print("smartadserver.com, 3797, RESELLER")
if 'publisherAccountId":"1692' not in response.text: print("smartadserver.com, 1692, RESELLER")
if 'publisherAccountId":"368' not in response.text: print("smartyads.com, 368, RESELLER")
if 'publisherAccountId":"283422' not in response.text: print("spotx.tv, 283422, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"283422' not in response.text: print("spotxchange.com, 283422, RESELLER, 7842df1d2fe2db34")
if 'publisherAccountId":"14039' not in response.text: print("tappx.com, 14039, RESELLER, 9f375a07da0318ec")
if 'publisherAccountId":"s92od-u4sw5' not in response.text: print("telaria.com, s92od-u4sw5, RESELLER, 1a4e959a1b50034a")
if 'publisherAccountId":"s92od-u4sw5' not in response.text: print("tremorhub.com, s92od-u4sw5, RESELLER, 1a4e959a1b50034a")
if 'publisherAccountId":"par-BE776B39322A364BC7767A69AB99BBD9' not in response.text: print("ucfunnel.com, par-BE776B39322A364BC7767A69AB99BBD9, RESELLER")
if 'publisherAccountId":"par-D233672DD744287DCD7E2439B82494AD' not in response.text: print("ucfunnel.com, par-D233672DD744287DCD7E2439B82494AD, RESELLER")
if 'publisherAccountId":"1010422' not in response.text: print("mars.media, 1010422, RESELLER, 8624339f102fb076")
if 'publisherAccountId":"6814' not in response.text: print("advertising.com, 6814, RESELLER")
if 'publisherAccountId":"805' not in response.text: print("beachfront.com, 805, RESELLER, e2541279e8e2ca4d")
if 'publisherAccountId":"1210' not in response.text: print("improvedigital.com, 1210, RESELLER")
if 'publisherAccountId":"1221' not in response.text: print("improvedigital.com, 1221, RESELLER")
if 'publisherAccountId":"12223' not in response.text: print("appnexus.com, 12223, RESELLER, f5ab79cb980f11d1")
if 'publisherAccountId":"1161393' not in response.text: print("freewheel.tv, 1161393, RESELLER")
if 'publisherAccountId":"160195' not in response.text: print("pubmatic.com, 160195, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"160194' not in response.text: print("pubmatic.com, 160194, RESELLER, 5d62403b186f2ace")
if 'publisherAccountId":"pub-7214269347534569' not in response.text: print("google.com, pub-7214269347534569, RESELLER, f08c47fec0942fa0")
if 'publisherAccountId":"1162449' not in response.text: print("freewheel.tv, 1162449, RESELLER")
if 'publisherAccountId":"XLV' not in response.text: print("gitberry.com, XLV, RESELLER")
if 'publisherAccountId":"5baa7ca93ef847c0876297e737dac3ee' not in response.text: print("inmobi.com, 5baa7ca93ef847c0876297e737dac3ee, RESELLER, 83e75a7ae333ca9d")
if 'publisherAccountId":"1173729' not in response.text: print("freewheel.tv, 1173729, RESELLER")
if 'publisherAccountId":"1173793' not in response.text: print("freewheel.tv, 1173793, RESELLER")
if 'publisherAccountId":"1339' not in response.text: print("gothamads.com, 1339,  RESELLER, d9c86e5dec870222")
if 'publisherAccountId":"13706' not in response.text: print("gumgum.com,13706,RESELLER,ffdef49475d318a9")
if 'publisherAccountId":"70101' not in response.text: print("webeyemob.com, 70101, RESELLER")
if 'publisherAccountId":"540679900' not in response.text: print("openx.com, 540679900, RESELLER, 6a698e2ec38604c6")
if 'publisherAccountId":"801e49d1be83b5f9' not in response.text: print("adcolony.com, 801e49d1be83b5f9, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"1192767' not in response.text: print("freewheel.tv, 1192767, RESELLER")
if 'publisherAccountId":"1192799' not in response.text: print("freewheel.tv, 1192799, RESELLER")
if 'publisherAccountId":"8613985ec49eb8f757ae6439e879bb2a6784' not in response.text: print("hitapps.com, 8613985ec49eb8f757ae6439e879bb2a6784, RESELLER")
if 'publisherAccountId":"66cff8e37d871be' not in response.text: print("onetag.com, 66cff8e37d871be, RESELLER")
if 'publisherAccountId":"1100042823' not in response.text: print("smaato.com, 1100042823, RESELLER, 07bcf65f187117b4")
if 'publisherAccountId":"7606' not in response.text: print("pokkt.com, 7606, RESELLER, c45702d9311e25fd")
if 'publisherAccountId":"107606' not in response.text: print("appads.in, 107606, RESELLER")
if 'publisherAccountId":"7d04a18a58085918' not in response.text: print("adcolony.com, 7d04a18a58085918, RESELLER, 1ad675c9de6b5176")
if 'publisherAccountId":"353' not in response.text: print("reforge.in, 353, RESELLER")
if 'publisherAccountId":"6' not in response.text: print("flat-ads.com, 6, RESELLER")
if 'publisherAccountId":"100293' not in response.text: print("conversantmedia.com, 100293, RESELLER, 03113cd04947736d")
if 'publisherAccountId":"59025' not in response.text: print("aol.com, 59025, RESELLER, e1a5b5b6e3255540")
if 'publisherAccountId":"59025' not in response.text: print("yahoo.com, 59025, RESELLER, e1a5b5b6e3255540")
if 'publisherAccountId":"32076181' not in response.text: print("adview.com,32076181,RESELLER,1b2cc038a11ea319")
if 'publisherAccountId":"1017355401' not in response.text: print("acexchange.co.kr,1017355401,RESELLER")
if 'publisherAccountId":"1081983882' not in response.text: print("acexchange.co.kr,1081983882,RESELLER")
if 'publisherAccountId":"1618149085' not in response.text: print("acexchange.co.kr,1618149085,RESELLER")
if 'publisherAccountId":"197af3936679d34e' not in response.text: print("adcolony.com,197af3936679d34e,RESELLER,1ad675c9de6b5176")
if 'publisherAccountId":"1efc6603710003ea' not in response.text: print("adcolony.com,1efc6603710003ea,RESELLER,1ad675c9de6b5176")
if 'publisherAccountId":"382d79cd1387e603' not in response.text: print("adcolony.com,382d79cd1387e603,RESELLER,1ad675c9de6b5176")
if 'publisherAccountId":"c490f6e7399a25d6' not in response.text: print("adcolony.com,c490f6e7399a25d6,RESELLER,1ad675c9de6b5176")
if 'publisherAccountId":"e8d70ef9dfabde92' not in response.text: print("adcolony.com,e8d70ef9dfabde92,RESELLER,1ad675c9de6b5176")
if 'publisherAccountId":"43' not in response.text: print("admanmedia.com,43,RESELLER")
if 'publisherAccountId":"48' not in response.text: print("admanmedia.com,48,RESELLER")
if 'publisherAccountId":"594' not in response.text: print("admanmedia.com,594,RESELLER")
if 'publisherAccountId":"1185' not in response.text: print("admixer.co.kr,1185,RESELLER")
if 'publisherAccountId":"1287' not in response.text: print("admixer.co.kr,1287,RESELLER")
if 'publisherAccountId":"de2ae535-59eb-4f0b-95e3-89f821933d47' not in response.text: print("admixer.net,de2ae535-59eb-4f0b-95e3-89f821933d47,RESELLER")
if 'publisherAccountId":"28246' not in response.text: print("advertising.com,28246,RESELLER")
if 'publisherAccountId":"b4bf4fdd9b0b915f746f6747ff432bde' not in response.text: print("adyoulike.com,b4bf4fdd9b0b915f746f6747ff432bde,RESELLER,4ad745ead2958bf7")
if 'publisherAccountId":"57992' not in response.text: print("aol.com,57992,RESELLER,e1a5b5b6e3255540")
if 'publisherAccountId":"58905' not in response.text: print("aol.com,58905,RESELLER,e1a5b5b6e3255540")
if 'publisherAccountId":"13099' not in response.text: print("appnexus.com,13099,RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"3703' not in response.text: print("appnexus.com,3703,RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"4052' not in response.text: print("appnexus.com,4052,RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"9569' not in response.text: print("appnexus.com,9569,RESELLER,f5ab79cb980f11d1")
if 'publisherAccountId":"par-2736764B3A38EB77FDEAEB7444AB844' not in response.text: print("aralego.com,par-2736764B3A38EB77FDEAEB7444AB844,RESELLER")
if 'publisherAccountId":"pub-77229E766E887DE6FB9ED63A78D6A629' not in response.text: print("aralego.com,pub-77229E766E887DE6FB9ED63A78D6A629,RESELLER")
if 'publisherAccountId":"56222' not in response.text: print("axonix.com,56222,RESELLER")
if 'publisherAccountId":"57264' not in response.text: print("axonix.com,57264,RESELLER")
if 'publisherAccountId":"57716' not in response.text: print("axonix.com,57716,RESELLER")
if 'publisherAccountId":"43092' not in response.text: print("betweendigital.com,43092,RESELLER")
if 'publisherAccountId":"43843' not in response.text: print("betweendigital.com,43843,RESELLER")
if 'publisherAccountId":"3de04db04d6eb28b13281a39b1c16d67' not in response.text: print("bidence.com,3de04db04d6eb28b13281a39b1c16d67,RESELLER")
if 'publisherAccountId":"33' not in response.text: print("blis.com,33,RESELLER,61453ae19a4b73f4")
if 'publisherAccountId":"560288' not in response.text: print("contextweb.com,560288,RESELLER,89ff185a4c4e857c")
if 'publisherAccountId":"561998' not in response.text: print("contextweb.com,561998,RESELLER,89ff185a4c4e857c")
if 'publisherAccountId":"562122' not in response.text: print("contextweb.com,562122,RESELLER,89ff185a4c4e857c")
if 'publisherAccountId":"100081' not in response.text: print("conversantmedia.com,100081,RESELLER,03113cd04947736d")
if 'publisherAccountId":"100246' not in response.text: print("conversantmedia.com,100246,RESELLER,03113cd04947736d")
if 'publisherAccountId":"40881' not in response.text: print("conversantmedia.com,40881,RESELLER,03113cd04947736d")
if 'publisherAccountId":"14' not in response.text: print("decenterads.com,14,RESELLER")
if 'publisherAccountId":"198' not in response.text: print("decenterads.com,198,RESELLER")
if 'publisherAccountId":"a15ce31379a418ac' not in response.text: print("e-planning.net,a15ce31379a418ac,RESELLER,c1ba615865ed87b2")
if 'publisherAccountId":"20393' not in response.text: print("freewheel.tv,20393,RESELLER")
if 'publisherAccountId":"24377' not in response.text: print("freewheel.tv,24377,RESELLER")
if 'publisherAccountId":"pub-3769010358500643' not in response.text: print("google.com,pub-3769010358500643,RESELLER,f08c47fec0942fa0")
if 'publisherAccountId":"pub-4568609371004228' not in response.text: print("google.com,pub-4568609371004228,RESELLER,f08c47fec0942fa0")
if 'publisherAccountId":"107' not in response.text: print("groundtruth.com,107,RESELLER,81cbf0a75a5e0e9a")
if 'publisherAccountId":"1331' not in response.text: print("improvedigital.com,1331,RESELLER")
if 'publisherAccountId":"1532' not in response.text: print("improvedigital.com,1532,RESELLER")
if 'publisherAccountId":"184738' not in response.text: print("indexexchange.com,184738,RESELLER,50b1c356f2c5c8fc")
if 'publisherAccountId":"191332' not in response.text: print("indexexchange.com,191332,RESELLER,50b1c356f2c5c8fc")
if 'publisherAccountId":"194730' not in response.text: print("indexexchange.com,194730,RESELLER,50b1c356f2c5c8fc")
if 'publisherAccountId":"61d733c3779d43e590c51c8bc078e10c' not in response.text: print("inmobi.com,61d733c3779d43e590c51c8bc078e10c,RESELLER,83e75a7ae333ca9d")
if 'publisherAccountId":"867c89bb53994aaeb9dae3ce75b03e78' not in response.text: print("inmobi.com,867c89bb53994aaeb9dae3ce75b03e78,RESELLER,83e75a7ae333ca9d")
if 'publisherAccountId":"ab915bcef5b24940bf745f1a8f427bec' not in response.text: print("inmobi.com,ab915bcef5b24940bf745f1a8f427bec,RESELLER,83e75a7ae333ca9d")
if 'publisherAccountId":"ec6f6ceb8bb1440ba5455644ec96c275' not in response.text: print("inmobi.com,ec6f6ceb8bb1440ba5455644ec96c275,RESELLER,83e75a7ae333ca9d")
if 'publisherAccountId":"647' not in response.text: print("lkqd.net,647,RESELLER,59c49fa9598a0117")
if 'publisherAccountId":"654' not in response.text: print("lkqd.net,654,RESELLER,59c49fa9598a0117")
if 'publisherAccountId":"10178' not in response.text: print("loopme.com,10178,RESELLER,6c8d5f95897a5a3b")
if 'publisherAccountId":"11322' not in response.text: print("loopme.com,11322,RESELLER,6c8d5f95897a5a3b")
if 'publisherAccountId":"5679' not in response.text: print("loopme.com,5679,RESELLER,6c8d5f95897a5a3b")
if 'publisherAccountId":"9724' not in response.text: print("loopme.com,9724,RESELLER,6c8d5f95897a5a3b")
if 'publisherAccountId":"102753' not in response.text: print("mars.media,102753,RESELLER")
if 'publisherAccountId":"59aa7be4921bac8' not in response.text: print("onetag.com,59aa7be4921bac8,RESELLER")
if 'publisherAccountId":"74ea58ae86fd4b0' not in response.text: print("onetag.com,74ea58ae86fd4b0,RESELLER")
if 'publisherAccountId":"537149888' not in response.text: print("openx.com,537149888,RESELLER,6a698e2ec38604c6")
if 'publisherAccountId":"540031703' not in response.text: print("openx.com,540031703,RESELLER,6a698e2ec38604c6")
if 'publisherAccountId":"540298543' not in response.text: print("openx.com,540298543,RESELLER,6a698e2ec38604c6")
if 'publisherAccountId":"540326226' not in response.text: print("openx.com,540326226,RESELLER,6a698e2ec38604c6")
if 'publisherAccountId":"7606' not in response.text: print("pokkt.com,7606,RESELLER,c45702d9311e25fd")
if 'publisherAccountId":"156439' not in response.text: print("pubmatic.com,156439,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"156835' not in response.text: print("pubmatic.com,156835,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"156931' not in response.text: print("pubmatic.com,156931,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"157097' not in response.text: print("pubmatic.com,157097,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"158100' not in response.text: print("pubmatic.com,158100,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"158154' not in response.text: print("pubmatic.com,158154,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"159035' not in response.text: print("pubmatic.com,159035,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"160145' not in response.text: print("pubmatic.com,160145,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"92509' not in response.text: print("pubmatic.com,92509,RESELLER,5d62403b186f2ace")
if 'publisherAccountId":"1006576' not in response.text: print("pubnative.net,1006576,RESELLER,d641df8625486a7b")
if 'publisherAccountId":"1006936' not in response.text: print("pubnative.net,1006936,RESELLER,d641df8625486a7b")
if 'publisherAccountId":"1006951' not in response.text: print("pubnative.net,1006951,RESELLER,d641df8625486a7b")
if 'publisherAccountId":"188404962' not in response.text: print("rhythmone.com,188404962,RESELLER,a670c89d4a324e47")
if 'publisherAccountId":"2564526802' not in response.text: print("rhythmone.com,2564526802,RESELLER,a670c89d4a324e47")
if 'publisherAccountId":"3218195319' not in response.text: print("rhythmone.com,3218195319,RESELLER,a670c89d4a324e47")
if 'publisherAccountId":"4173858586' not in response.text: print("rhythmone.com,4173858586,RESELLER,a670c89d4a324e47")
if 'publisherAccountId":"11726' not in response.text: print("rubiconproject.com,11726,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"12266' not in response.text: print("rubiconproject.com,12266,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"13856' not in response.text: print("rubiconproject.com,13856,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"16114' not in response.text: print("rubiconproject.com,16114,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"17328' not in response.text: print("rubiconproject.com,17328,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"19724' not in response.text: print("rubiconproject.com,19724,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"20744' not in response.text: print("rubiconproject.com,20744,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"23644' not in response.text: print("rubiconproject.com,23644,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"23732' not in response.text: print("rubiconproject.com,23732,RESELLER,0bfd66d529a55807")
if 'publisherAccountId":"1100044045' not in response.text: print("smaato.com,1100044045,RESELLER,07bcf65f187117b4")
if 'publisherAccountId":"1100049757' not in response.text: print("smaato.com,1100049757,RESELLER,07bcf65f187117b4")
if 'publisherAccountId":"1692' not in response.text: print("smartadserver.com,1692,RESELLER")
if 'publisherAccountId":"3232' not in response.text: print("smartadserver.com,3232,RESELLER")
if 'publisherAccountId":"3797' not in response.text: print("smartadserver.com,3797,RESELLER")
if 'publisherAccountId":"4071' not in response.text: print("smartadserver.com,4071,RESELLER")
if 'publisherAccountId":"4111' not in response.text: print("smartadserver.com,4111,RESELLER")
if 'publisherAccountId":"cc3858f35e' not in response.text: print("sonobi.com,cc3858f35e,RESELLER,d1a215d9eb5aee9e")
if 'publisherAccountId":"eaec54c63f' not in response.text: print("sonobi.com,eaec54c63f,RESELLER,d1a215d9eb5aee9e")
if 'publisherAccountId":"82068' not in response.text: print("spotx.tv,82068,RESELLER,7842df1d2fe2db34")
if 'publisherAccountId":"82068' not in response.text: print("spotxchange.com,82068,RESELLER,7842df1d2fe2db34")
if 'publisherAccountId":"14039' not in response.text: print("tappx.com,14039,RESELLER,9f375a07da0318ec")
if 'publisherAccountId":"368' not in response.text: print("tpmn.io,368,RESELLER")
if 'publisherAccountId":"406' not in response.text: print("tpmn.io,406,RESELLER")
if 'publisherAccountId":"15290' not in response.text: print("verve.com,15290,RESELLER,0c8f5958fc2d6270")
if 'publisherAccountId":"15503' not in response.text: print("verve.com,15503,RESELLER,0c8f5958fc2d6270")
if 'publisherAccountId":"5897' not in response.text: print("verve.com,5897,RESELLER,0c8f5958fc2d6270")
if 'publisherAccountId":"958' not in response.text: print("xad.com,958,RESELLER,81cbf0a75a5e0e9a")
if 'publisherAccountId":"55771' not in response.text: print("yahoo.com,55771,RESELLER,e1a5b5b6e3255540")
if 'publisherAccountId":"57992' not in response.text: print("yahoo.com,57992,RESELLER,e1a5b5b6e3255540")
if 'publisherAccountId":"58905' not in response.text: print("yahoo.com,58905,RESELLER,e1a5b5b6e3255540")
# Out:
# gothamads.com, 1339,  RESELLER, d9c86e5dec870222
# gumgum.com,13706,RESELLER,ffdef49475d318a9
# webeyemob.com, 70101, RESELLER
# freewheel.tv, 1192767, RESELLER
# freewheel.tv, 1192799, RESELLER
# hitapps.com, 8613985ec49eb8f757ae6439e879bb2a6784, RESELLER
# adcolony.com, 7d04a18a58085918, RESELLER, 1ad675c9de6b5176
# aol.com, 59025, RESELLER, e1a5b5b6e3255540
# yahoo.com, 59025, RESELLER, e1a5b5b6e3255540
# acexchange.co.kr,1017355401,RESELLER
# acexchange.co.kr,1081983882,RESELLER
# acexchange.co.kr,1618149085,RESELLER
# admixer.co.kr,1185,RESELLER
# adyoulike.com,b4bf4fdd9b0b915f746f6747ff432bde,RESELLER,4ad745ead2958bf7
# appnexus.com,13099,RESELLER,f5ab79cb980f11d1
# aralego.com,par-2736764B3A38EB77FDEAEB7444AB844,RESELLER
# aralego.com,pub-77229E766E887DE6FB9ED63A78D6A629,RESELLER
# betweendigital.com,43843,RESELLER
# bidence.com,3de04db04d6eb28b13281a39b1c16d67,RESELLER
# contextweb.com,560288,RESELLER,89ff185a4c4e857c
# contextweb.com,561998,RESELLER,89ff185a4c4e857c
# ...
